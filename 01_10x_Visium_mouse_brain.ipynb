# %%
suppressMessages(library(scDesign3))
suppressMessages(library(scales))
suppressMessages(library(dplyr))
suppressMessages(library(ggplot2))
suppressMessages(library(cowplot))
suppressMessages(library(Seurat))
suppressMessages(library(SingleCellExperiment))
suppressMessages(library(anndata))
set.seed(2024)

# %%
output_dir <- '../../01_generate_simulate_data/01_10x_Visium_mouse_brain'

if(!dir.exists(output_dir)){
    dir.create(output_dir, recursive = TRUE)
}

# %%
installed.packages()
# Out:
#              Package      LibPath
# abind        abind        C:/Users/User/AppData/Local/R/win-library/4.4
# anndata      anndata      C:/Users/User/AppData/Local/R/win-library/4.4
# askpass      askpass      C:/Users/User/AppData/Local/R/win-library/4.4
# assertthat   assertthat   C:/Users/User/AppData/Local/R/win-library/4.4
# backports    backports    C:/Users/User/AppData/Local/R/win-library/4.4
# base64enc    base64enc    C:/Users/User/AppData/Local/R/win-library/4.4
# BH           BH           C:/Users/User/AppData/Local/R/win-library/4.4
# Biobase      Biobase      C:/Users/User/AppData/Local/R/win-library/4.4
# BiocGenerics BiocGenerics C:/Users/User/AppData/Local/R/win-library/4.4
# BiocManager  BiocManager  C:/Users/User/AppData/Local/R/win-library/4.4
# BiocParallel BiocParallel C:/Users/User/AppData/Local/R/win-library/4.4
# BiocVersion  BiocVersion  C:/Users/User/AppData/Local/R/win-library/4.4
# bitops       bitops       C:/Users/User/AppData/Local/R/win-library/4.4
# brew         brew         C:/Users/User/AppData/Local/R/win-library/4.4
# bslib        bslib        C:/Users/User/AppData/Local/R/win-library/4.4
# cachem       cachem       C:/Users/User/AppData/Local/R/win-library/4.4
# callr        callr        C:/Users/User/AppData/Local/R/win-library/4.4
# caTools      caTools      C:/Users/User/AppData/Local/R/win-library/4.4
# cli          cli          C:/Users/User/AppData/Local/R/win-library/4.4
# collections  collections  C:/Users/User/AppData/Local/R/win-library/4.4
# colorspace   colorspace   C:/Users/User/AppData/Local/R/win-library/4.4
# commonmark   commonmark   C:/Users/User/AppData/Local/R/win-library/4.4
# coop         coop         C:/Users/User/AppData/Local/R/win-library/4.4
# cowplot      cowplot      C:/Users/User/AppData/Local/R/win-library/4.4
# cpp11        cpp11        C:/Users/User/AppData/Local/R/win-library/4.4
# crayon       crayon       C:/Users/User/AppData/Local/R/win-library/4.4
# crosstalk    crosstalk    C:/Users/User/AppData/Local/R/win-library/4.4
# curl         curl         C:/Users/User/AppData/Local/R/win-library/4.4
# cyclocomp    cyclocomp    C:/Users/User/AppData/Local/R/win-library/4.4
# data.table   data.table   C:/Users/User/AppData/Local/R/win-library/4.4
# ⋮            ⋮            ⋮
# base         base         C:/Program Files/R/R-4.4.1/library
# boot         boot         C:/Program Files/R/R-4.4.1/library
# class        class        C:/Program Files/R/R-4.4.1/library
# cluster      cluster      C:/Program Files/R/R-4.4.1/library
# codetools    codetools    C:/Program Files/R/R-4.4.1/library
# compiler     compiler     C:/Program Files/R/R-4.4.1/library
# datasets     datasets     C:/Program Files/R/R-4.4.1/library
# foreign      foreign      C:/Program Files/R/R-4.4.1/library
# graphics     graphics     C:/Program Files/R/R-4.4.1/library
# grDevices    grDevices    C:/Program Files/R/R-4.4.1/library
# grid         grid         C:/Program Files/R/R-4.4.1/library
# KernSmooth   KernSmooth   C:/Program Files/R/R-4.4.1/library
# lattice      lattice      C:/Program Files/R/R-4.4.1/library
# MASS         MASS         C:/Program Files/R/R-4.4.1/library
# Matrix       Matrix       C:/Program Files/R/R-4.4.1/library
# methods      methods      C:/Program Files/R/R-4.4.1/library
# mgcv         mgcv         C:/Program Files/R/R-4.4.1/library
# nlme         nlme         C:/Program Files/R/R-4.4.1/library
# nnet         nnet         C:/Program Files/R/R-4.4.1/library
# parallel     parallel     C:/Program Files/R/R-4.4.1/library
# rpart        rpart        C:/Program Files/R/R-4.4.1/library
# spatial      spatial      C:/Program Files/R/R-4.4.1/library
# splines      splines      C:/Program Files/R/R-4.4.1/library
# stats        stats        C:/Program Files/R/R-4.4.1/library
# stats4       stats4       C:/Program Files/R/R-4.4.1/library
# survival     survival     C:/Program Files/R/R-4.4.1/library
# tcltk        tcltk        C:/Program Files/R/R-4.4.1/library
# tools        tools        C:/Program Files/R/R-4.4.1/library
# translations translations C:/Program Files/R/R-4.4.1/library
# utils        utils        C:/Program Files/R/R-4.4.1/library
#              Version  Priority
# abind        1.4-5    NA
# anndata      0.7.5.6  NA
# askpass      1.2.0    NA
# assertthat   0.2.1    NA
# backports    1.5.0    NA
# base64enc    0.1-3    NA
# BH           1.84.0-0 NA
# Biobase      2.64.0   NA
# BiocGenerics 0.50.0   NA
# BiocManager  1.30.23  NA
# BiocParallel 1.38.0   NA
# BiocVersion  3.19.1   NA
# bitops       1.0-7    NA
# brew         1.0-10   NA
# bslib        0.7.0    NA
# cachem       1.1.0    NA
# callr        3.7.6    NA
# caTools      1.18.2   NA
# cli          3.6.3    NA
# collections  0.3.7    NA
# colorspace   2.1-0    NA
# commonmark   1.9.1    NA
# coop         0.6-3    NA
# cowplot      1.1.3    NA
# cpp11        0.4.7    NA
# crayon       1.5.3    NA
# crosstalk    1.2.1    NA
# curl         5.2.1    NA
# cyclocomp    1.1.1    NA
# data.table   1.15.4   NA
# ⋮            ⋮        ⋮
# base         4.4.1    base
# boot         1.3-30   recommended
# class        7.3-22   recommended
# cluster      2.1.6    recommended
# codetools    0.2-20   recommended
# compiler     4.4.1    base
# datasets     4.4.1    base
# foreign      0.8-86   recommended
# graphics     4.4.1    base
# grDevices    4.4.1    base
# grid         4.4.1    base
# KernSmooth   2.23-24  recommended
# lattice      0.22-6   recommended
# MASS         7.3-60.2 recommended
# Matrix       1.7-0    recommended
# methods      4.4.1    base
# mgcv         1.9-1    recommended
# nlme         3.1-164  recommended
# nnet         7.3-19   recommended
# parallel     4.4.1    base
# rpart        4.1.23   recommended
# spatial      7.3-17   recommended
# splines      4.4.1    base
# stats        4.4.1    base
# stats4       4.4.1    base
# survival     3.6-4    recommended
# tcltk        4.4.1    base
# tools        4.4.1    base
# translations 4.4.1    NA
# utils        4.4.1    base
#              Depends
# abind        R (>= 1.5.0)
# anndata      R (>= 3.5.0)
# askpass      NA
# assertthat   NA
# backports    R (>= 3.0.0)
# base64enc    R (>= 2.9.0)
# BH           NA
# Biobase      R (>= 2.10), BiocGenerics (>= 0.27.1), utils
# BiocGenerics R (>= 4.0.0), methods, utils, graphics, stats
# BiocManager  NA
# BiocParallel methods, R (>= 3.5.0)
# BiocVersion  R (>= 4.4.0)
# bitops       NA
# brew         NA
# bslib        R (>= 2.10)
# cachem       NA
# callr        R (>= 3.4)
# caTools      R (>= 3.6.0)
# cli          R (>= 3.4)
# collections  NA
# colorspace   R (>= 3.0.0), methods
# commonmark   NA
# coop         R (>= 3.1.0)
# cowplot      R (>= 3.5.0)
# cpp11        R (>= 3.5.0)
# crayon       NA
# crosstalk    NA
# curl         R (>= 3.0.0)
# cyclocomp    NA
# data.table   R (>= 3.1.0)
# ⋮            ⋮
# base         NA
# boot         R (>= 3.0.0), graphics, stats
# class        R (>= 3.0.0), stats, utils
# cluster      R (>= 3.5.0)
# codetools    R (>= 2.1)
# compiler     NA
# datasets     NA
# foreign      R (>= 4.0.0)
# graphics     NA
# grDevices    NA
# grid         NA
# KernSmooth   R (>= 2.5.0), stats
# lattice      R (>= 4.0.0)
# MASS         R (>= 4.4.0), grDevices, graphics, stats, utils
# Matrix       R (>= 4.4.0), methods
# methods      NA
# mgcv         R (>= 3.6.0), nlme (>= 3.1-64)
# nlme         R (>= 3.5.0)
# nnet         R (>= 3.0.0), stats, utils
# parallel     NA
# rpart        R (>= 2.15.0), graphics, stats, grDevices
# spatial      R (>= 3.0.0), graphics, stats, utils
# splines      NA
# stats        NA
# stats4       NA
# survival     R (>= 3.5.0)
# tcltk        NA
# tools        NA
# translations NA
# utils        NA
#              Imports
# abind        methods, utils
# anndata      assertthat, Matrix, methods, R6, reticulate (>= 1.17)
# askpass      sys (>= 2.1)
# assertthat   tools
# backports    NA
# base64enc    NA
# BH           NA
# Biobase      methods
# BiocGenerics methods, utils, graphics, stats
# BiocManager  utils
# BiocParallel stats, utils, futile.logger, parallel, snow, codetools
# BiocVersion  NA
# bitops       NA
# brew         NA
# bslib        base64enc, cachem, fastmap (>= 1.1.1), grDevices, htmltools\n(>= 0.5.8), jquerylib (>= 0.1.3), jsonlite, lifecycle, memoise\n(>= 2.0.1), mime, rlang, sass (>= 0.4.9)
# cachem       rlang, fastmap (>= 1.2.0)
# callr        processx (>= 3.6.1), R6, utils
# caTools      bitops
# cli          utils
# collections  NA
# colorspace   graphics, grDevices, stats
# commonmark   NA
# coop         NA
# cowplot      ggplot2 (>= 3.4.0), grid, gtable, grDevices, methods, rlang,\nscales
# cpp11        NA
# crayon       grDevices, methods, utils
# crosstalk    htmltools (>= 0.3.6), jsonlite, lazyeval, R6
# curl         NA
# cyclocomp    callr, crayon, desc, remotes, withr
# data.table   methods
# ⋮            ⋮
# base         NA
# boot         NA
# class        MASS
# cluster      graphics, grDevices, stats, utils
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      methods, utils, stats
# graphics     grDevices
# grDevices    NA
# grid         grDevices, utils
# KernSmooth   NA
# lattice      grid, grDevices, graphics, stats, utils
# MASS         methods
# Matrix       grDevices, graphics, grid, lattice, stats, utils
# methods      utils, stats
# mgcv         methods, stats, graphics, Matrix, splines, utils
# nlme         graphics, stats, utils, lattice
# nnet         NA
# parallel     tools, compiler
# rpart        NA
# spatial      NA
# splines      graphics, stats
# stats        utils, grDevices, graphics
# stats4       graphics, methods, stats
# survival     graphics, Matrix, methods, splines, stats, utils
# tcltk        utils
# tools        NA
# translations NA
# utils        NA
#              LinkingTo
# abind        NA
# anndata      NA
# askpass      NA
# assertthat   NA
# backports    NA
# base64enc    NA
# BH           NA
# Biobase      NA
# BiocGenerics NA
# BiocManager  NA
# BiocParallel BH, cpp11
# BiocVersion  NA
# bitops       NA
# brew         NA
# bslib        NA
# cachem       NA
# callr        NA
# caTools      NA
# cli          NA
# collections  NA
# colorspace   NA
# commonmark   NA
# coop         NA
# cowplot      NA
# cpp11        NA
# crayon       NA
# crosstalk    NA
# curl         NA
# cyclocomp    NA
# data.table   NA
# ⋮            ⋮
# base         NA
# boot         NA
# class        NA
# cluster      NA
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      NA
# graphics     NA
# grDevices    NA
# grid         NA
# KernSmooth   NA
# lattice      NA
# MASS         NA
# Matrix       NA
# methods      NA
# mgcv         NA
# nlme         NA
# nnet         NA
# parallel     NA
# rpart        NA
# spatial      NA
# splines      NA
# stats        NA
# stats4       NA
# survival     NA
# tcltk        NA
# tools        NA
# translations NA
# utils        NA
#              Suggests
# abind        NA
# anndata      stats, testthat, knitr, rmarkdown
# askpass      testthat
# assertthat   testthat, covr
# backports    NA
# base64enc    NA
# BH           NA
# Biobase      tools, tkWidgets, ALL, RUnit, golubEsets, BiocStyle, knitr,\nlimma
# BiocGenerics Biobase, S4Vectors, IRanges, GenomicRanges, DelayedArray,\nBiostrings, Rsamtools, AnnotationDbi, affy, affyPLM, DESeq2,\nflowClust, MSnbase, annotate, RUnit
# BiocManager  BiocVersion, BiocStyle, remotes, rmarkdown, testthat, withr,\ncurl, knitr
# BiocParallel BiocGenerics, tools, foreach, BBmisc, doParallel,\nGenomicRanges, RNAseqData.HNRNPC.bam.chr14,\nTxDb.Hsapiens.UCSC.hg19.knownGene, VariantAnnotation,\nRsamtools, GenomicAlignments, ShortRead, RUnit, BiocStyle,\nknitr, batchtools, data.table
# BiocVersion  NA
# bitops       NA
# brew         testthat (>= 3.0.0)
# bslib        bsicons, curl, fontawesome, future, ggplot2, knitr, magrittr,\nrappdirs, rmarkdown (>= 2.7), shiny (>= 1.8.1), testthat,\nthematic, withr
# cachem       testthat
# callr        asciicast (>= 2.3.1), cli (>= 1.1.0), mockery, ps, rprojroot,\nspelling, testthat (>= 3.2.0), withr (>= 2.3.0)
# caTools      MASS, rpart
# cli          callr, covr, crayon, digest, glue (>= 1.6.0), grDevices,\nhtmltools, htmlwidgets, knitr, methods, mockery, processx, ps\n(>= 1.3.4.9000), rlang (>= 1.0.2.9003), rmarkdown, rprojroot,\nrstudioapi, testthat, tibble, whoami, withr
# collections  testthat (>= 2.3.1)
# colorspace   datasets, utils, KernSmooth, MASS, kernlab, mvtnorm, vcd,\ntcltk, shiny, shinyjs, ggplot2, dplyr, scales, grid, png, jpeg,\nknitr, rmarkdown, RColorBrewer, rcartocolor, scico, viridis,\nwesanderson
# commonmark   curl, testthat, xml2
# coop         memuse
# cowplot      Cairo, covr, dplyr, forcats, gridGraphics (>= 0.4-0), knitr,\nlattice, magick, maps, PASWR, patchwork, rmarkdown, ragg,\ntestthat (>= 1.0.0), tidyr, vdiffr (>= 0.3.0), VennDiagram
# cpp11        bench, brio, callr, cli, covr, decor, desc, ggplot2, glue,\nknitr, lobstr, mockery, progress, rmarkdown, scales, Rcpp,\ntestthat (>= 3.2.0), tibble, utils, vctrs, withr
# crayon       mockery, rstudioapi, testthat, withr
# crosstalk    shiny, ggplot2, testthat (>= 2.1.0), sass, bslib
# curl         spelling, testthat (>= 1.0.0), knitr, jsonlite, later,\nrmarkdown, httpuv (>= 1.4.4), webutils
# cyclocomp    testthat
# data.table   bit64 (>= 4.0.0), bit (>= 4.0.4), R.utils, xts, zoo (>=\n1.8-1), yaml, knitr, markdown
# ⋮            ⋮
# base         methods
# boot         MASS, survival
# class        NA
# cluster      MASS, Matrix
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      NA
# graphics     NA
# grDevices    KernSmooth
# grid         NA
# KernSmooth   MASS, carData
# lattice      KernSmooth, MASS, latticeExtra, colorspace
# MASS         lattice, nlme, nnet, survival
# Matrix       MASS, datasets, sfsmisc, tools
# methods      codetools
# mgcv         parallel, survival, MASS
# nlme         Hmisc, MASS, SASmixed
# nnet         MASS
# parallel     methods
# rpart        survival
# spatial      MASS
# splines      Matrix, methods
# stats        MASS, Matrix, SuppDists, methods, stats4
# stats4       NA
# survival     NA
# tcltk        NA
# tools        codetools, methods, xml2, curl, commonmark, knitr, xfun,\nmathjaxr, V8
# translations NA
# utils        methods, xml2, commonmark, knitr, jsonlite
#              Enhances
# abind        NA
# anndata      NA
# askpass      NA
# assertthat   NA
# backports    NA
# base64enc    png
# BH           NA
# Biobase      NA
# BiocGenerics NA
# BiocManager  NA
# BiocParallel Rmpi
# BiocVersion  NA
# bitops       NA
# brew         NA
# bslib        NA
# cachem       NA
# callr        NA
# caTools      NA
# cli          NA
# collections  NA
# colorspace   NA
# commonmark   NA
# coop         slam (>= 0.1.32), Matrix
# cowplot      NA
# cpp11        NA
# crayon       NA
# crosstalk    NA
# curl         NA
# cyclocomp    NA
# data.table   NA
# ⋮            ⋮
# base         chron, date, round
# boot         NA
# class        NA
# cluster      mvoutlier, fpc, ellipse, sfsmisc
# codetools    NA
# compiler     NA
# datasets     NA
# foreign      NA
# graphics     vcd
# grDevices    NA
# grid         NA
# KernSmooth   NA
# lattice      chron, zoo
# MASS         NA
# Matrix       SparseM, graph
# methods      NA
# mgcv         NA
# nlme         NA
# nnet         NA
# parallel     snow, Rmpi
# rpart        NA
# spatial      NA
# splines      NA
# stats        Kendall, coin, multcomp, pcaPP, pspearman, robustbase
# stats4       NA
# survival     NA
# tcltk        NA
# tools        NA
# translations NA
# utils        NA
#              License                             License_is_FOSS
# abind        LGPL (>= 2)                         NA
# anndata      MIT + file LICENSE                  NA
# askpass      MIT + file LICENSE                  NA
# assertthat   GPL-3                               NA
# backports    GPL-2 | GPL-3                       NA
# base64enc    GPL-2 | GPL-3                       NA
# BH           BSL-1.0                             NA
# Biobase      Artistic-2.0                        NA
# BiocGenerics Artistic-2.0                        NA
# BiocManager  Artistic-2.0                        NA
# BiocParallel GPL-2 | GPL-3                       NA
# BiocVersion  Artistic-2.0                        NA
# bitops       GPL (>= 2)                          NA
# brew         GPL (>= 2)                          NA
# bslib        MIT + file LICENSE                  NA
# cachem       MIT + file LICENSE                  NA
# callr        MIT + file LICENSE                  NA
# caTools      GPL-3                               NA
# cli          MIT + file LICENSE                  NA
# collections  MIT + file LICENSE                  NA
# colorspace   BSD_3_clause + file LICENSE         NA
# commonmark   BSD_2_clause + file LICENSE         NA
# coop         BSD 2-clause License + file LICENSE NA
# cowplot      GPL-2                               NA
# cpp11        MIT + file LICENSE                  NA
# crayon       MIT + file LICENSE                  NA
# crosstalk    MIT + file LICENSE                  NA
# curl         MIT + file LICENSE                  NA
# cyclocomp    MIT + file LICENSE                  NA
# data.table   MPL-2.0 | file LICENSE              NA
# ⋮            ⋮                                   ⋮
# base         Part of R 4.4.1                     NA
# boot         Unlimited                           NA
# class        GPL-2 | GPL-3                       NA
# cluster      GPL (>= 2)                          NA
# codetools    GPL                                 NA
# compiler     Part of R 4.4.1                     NA
# datasets     Part of R 4.4.1                     NA
# foreign      GPL (>= 2)                          NA
# graphics     Part of R 4.4.1                     NA
# grDevices    Part of R 4.4.1                     NA
# grid         Part of R 4.4.1                     NA
# KernSmooth   Unlimited                           NA
# lattice      GPL (>= 2)                          NA
# MASS         GPL-2 | GPL-3                       NA
# Matrix       GPL (>= 2) | file LICENCE           NA
# methods      Part of R 4.4.1                     NA
# mgcv         GPL (>= 2)                          NA
# nlme         GPL (>= 2)                          NA
# nnet         GPL-2 | GPL-3                       NA
# parallel     Part of R 4.4.1                     NA
# rpart        GPL-2 | GPL-3                       NA
# spatial      GPL-2 | GPL-3                       NA
# splines      Part of R 4.4.1                     NA
# stats        Part of R 4.4.1                     NA
# stats4       Part of R 4.4.1                     NA
# survival     LGPL (>= 2)                         NA
# tcltk        Part of R 4.4.1                     NA
# tools        Part of R 4.4.1                     NA
# translations Part of R 4.4.1                     NA
# utils        Part of R 4.4.1                     NA
#              License_restricts_use OS_type MD5sum NeedsCompilation Built
# abind        NA                    NA      NA     no               4.4.0
# anndata      NA                    NA      NA     no               4.4.1
# askpass      NA                    NA      NA     yes              4.4.1
# assertthat   NA                    NA      NA     no               4.4.1
# backports    NA                    NA      NA     yes              4.4.0
# base64enc    NA                    NA      NA     yes              4.4.0
# BH           NA                    NA      NA     no               4.4.0
# Biobase      NA                    NA      NA     yes              4.4.0
# BiocGenerics NA                    NA      NA     no               4.4.0
# BiocManager  NA                    NA      NA     no               4.4.1
# BiocParallel NA                    NA      NA     yes              4.4.0
# BiocVersion  NA                    NA      NA     no               4.4.0
# bitops       NA                    NA      NA     yes              4.4.0
# brew         NA                    NA      NA     no               4.4.1
# bslib        NA                    NA      NA     no               4.4.1
# cachem       NA                    NA      NA     yes              4.4.1
# callr        NA                    NA      NA     no               4.4.1
# caTools      NA                    NA      NA     yes              4.4.1
# cli          NA                    NA      NA     yes              4.4.1
# collections  NA                    NA      NA     yes              4.4.1
# colorspace   NA                    NA      NA     yes              4.4.1
# commonmark   NA                    NA      NA     yes              4.4.1
# coop         NA                    NA      NA     yes              4.4.0
# cowplot      NA                    NA      NA     no               4.4.1
# cpp11        NA                    NA      NA     no               4.4.1
# crayon       NA                    NA      NA     no               4.4.1
# crosstalk    NA                    NA      NA     no               4.4.1
# curl         NA                    NA      NA     yes              4.4.1
# cyclocomp    NA                    NA      NA     no               4.4.1
# data.table   NA                    NA      NA     yes              4.4.1
# ⋮            ⋮                     ⋮       ⋮      ⋮                ⋮
# base         NA                    NA      NA     NA               4.4.1
# boot         NA                    NA      NA     no               4.4.1
# class        NA                    NA      NA     yes              4.4.1
# cluster      NA                    NA      NA     yes              4.4.1
# codetools    NA                    NA      NA     no               4.4.1
# compiler     NA                    NA      NA     NA               4.4.1
# datasets     NA                    NA      NA     NA               4.4.1
# foreign      NA                    NA      NA     yes              4.4.1
# graphics     NA                    NA      NA     yes              4.4.1
# grDevices    NA                    NA      NA     yes              4.4.1
# grid         NA                    NA      NA     yes              4.4.1
# KernSmooth   NA                    NA      NA     yes              4.4.1
# lattice      NA                    NA      NA     yes              4.4.1
# MASS         NA                    NA      NA     yes              4.4.1
# Matrix       NA                    NA      NA     yes              4.4.1
# methods      NA                    NA      NA     yes              4.4.1
# mgcv         NA                    NA      NA     yes              4.4.1
# nlme         NA                    NA      NA     yes              4.4.1
# nnet         NA                    NA      NA     yes              4.4.1
# parallel     NA                    NA      NA     yes              4.4.1
# rpart        NA                    NA      NA     yes              4.4.1
# spatial      NA                    NA      NA     yes              4.4.1
# splines      NA                    NA      NA     yes              4.4.1
# stats        NA                    NA      NA     yes              4.4.1
# stats4       NA                    NA      NA     NA               4.4.1
# survival     NA                    NA      NA     yes              4.4.1
# tcltk        NA                    NA      NA     yes              4.4.1
# tools        NA                    NA      NA     yes              4.4.1
# translations NA                    NA      NA     NA               4.4.1
# utils        NA                    NA      NA     yes              4.4.1

# %%
install.packages("anndata")
# Out:
# Warning message:
# "package 'anndata' is in use and will not be installed"

# %%
reticulate::install_miniconda()
anndata::install_anndata()
# Out:
# Error: Miniconda is already installed at path "C:/Users/User/AppData/Local/r-miniconda".
# - Use `reticulate::install_miniconda(force = TRUE)` to overwrite the previous installation.
# Traceback:
#
# 1. reticulate::install_miniconda()
# 2. install_miniconda_preflight(path, force)
# 3. stopf(fmt, pretty_path(path))
# 4. stop(sprintf(fmt, ...), call. = call.)

# %%
install.packages("devtools")
devtools::install_github('satijalab/seurat-data')
library(SeuratData)
# Out:
# Installing package into 'C:/Users/User/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'credentials', 'zip', 'gitcreds', 'ini', 'systemfonts', 'textshaping', 'diffobj', 'rematch2', 'clipr', 'gert', 'gh', 'rstudioapi', 'whisker', 'downlit', 'httr2', 'ragg', 'prettyunits', 'xopen', 'brio', 'praise', 'waldo', 'usethis', 'ellipsis', 'pkgdown', 'profvis', 'rcmdcheck', 'rversions', 'sessioninfo', 'testthat', 'urlchecker'
# package 'credentials' successfully unpacked and MD5 sums checked
# package 'zip' successfully unpacked and MD5 sums checked
# package 'gitcreds' successfully unpacked and MD5 sums checked
# package 'ini' successfully unpacked and MD5 sums checked
# package 'systemfonts' successfully unpacked and MD5 sums checked
# package 'textshaping' successfully unpacked and MD5 sums checked
# package 'diffobj' successfully unpacked and MD5 sums checked
# package 'rematch2' successfully unpacked and MD5 sums checked
# package 'clipr' successfully unpacked and MD5 sums checked
# package 'gert' successfully unpacked and MD5 sums checked
# package 'gh' successfully unpacked and MD5 sums checked
# package 'rstudioapi' successfully unpacked and MD5 sums checked
# package 'whisker' successfully unpacked and MD5 sums checked
# package 'downlit' successfully unpacked and MD5 sums checked
# package 'httr2' successfully unpacked and MD5 sums checked
# package 'ragg' successfully unpacked and MD5 sums checked
# package 'prettyunits' successfully unpacked and MD5 sums checked
# package 'xopen' successfully unpacked and MD5 sums checked
# package 'brio' successfully unpacked and MD5 sums checked
# package 'praise' successfully unpacked and MD5 sums checked
# package 'waldo' successfully unpacked and MD5 sums checked
# package 'usethis' successfully unpacked and MD5 sums checked
# package 'ellipsis' successfully unpacked and MD5 sums checked
# package 'pkgdown' successfully unpacked and MD5 sums checked
# package 'profvis' successfully unpacked and MD5 sums checked
# package 'rcmdcheck' successfully unpacked and MD5 sums checked
# package 'rversions' successfully unpacked and MD5 sums checked
# package 'sessioninfo' successfully unpacked and MD5 sums checked
# package 'testthat' successfully unpacked and MD5 sums checked
# package 'urlchecker' successfully unpacked and MD5 sums checked
# package 'devtools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\RtmpSy0JE2\downloaded_packages
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo satijalab/seurat-data@HEAD
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file 'C:\Users\User\AppData\Local\Temp\RtmpSy0JE2\remotes25144dee7dc0\satijalab-seurat-data-4dc08e0/DESCRIPTION' ... OK
# * preparing 'SeuratData':
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Omitted 'LazyData' from DESCRIPTION
# * building 'SeuratData_0.2.2.9001.tar.gz'
# Installing package into 'C:/Users/User/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)

# %%
BiocManager::install("scp")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.19 (BiocManager 1.30.23), R 4.4.1 (2024-06-14 ucrt)
#
# Installing package(s) 'scp'
#
# also installing the dependencies 'ProtGenerics', 'AnnotationFilter', 'slam', 'lpsymphony', 'fdrtool', 'clue', 'BiocBaseUtils', 'QFeatures', 'IHW', 'metapod', 'MsCoreUtils', 'MultiAssayExperiment', 'nipals'
# package 'ProtGenerics' successfully unpacked and MD5 sums checked
# package 'AnnotationFilter' successfully unpacked and MD5 sums checked
# package 'slam' successfully unpacked and MD5 sums checked
# package 'lpsymphony' successfully unpacked and MD5 sums checked
# package 'fdrtool' successfully unpacked and MD5 sums checked
# package 'clue' successfully unpacked and MD5 sums checked
# package 'BiocBaseUtils' successfully unpacked and MD5 sums checked
# package 'QFeatures' successfully unpacked and MD5 sums checked
# package 'IHW' successfully unpacked and MD5 sums checked
# package 'metapod' successfully unpacked and MD5 sums checked
# package 'MsCoreUtils' successfully unpacked and MD5 sums checked
# package 'MultiAssayExperiment' successfully unpacked and MD5 sums checked
# package 'nipals' successfully unpacked and MD5 sums checked
# package 'scp' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\RtmpSy0JE2\downloaded_packages
# Installation paths not writeable, unable to update packages
#   path: C:/Program Files/R/R-4.4.1/library
#   packages:
#     foreign, MASS, nlme, survival
#
# Old packages: 'hdf5r', 'IRanges', 'RcppArmadillo', 'S4Vectors'
